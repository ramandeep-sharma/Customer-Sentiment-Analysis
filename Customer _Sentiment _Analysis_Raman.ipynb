# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.34.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3~=2.4.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.4.26 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from selenium) (2025.4.26)
# Collecting typing_extensions~=4.14.0 (from selenium)
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Collecting sortedcontainers (from trio~=0.30.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from trio~=0.30.0->selenium) (3.10)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from trio~=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]~=2.4.0->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pycparser in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.34.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.4 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.4 MB 2.5 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.4 MB 2.9 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.4 MB 3.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.4 MB 3.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.4 MB 3.6 MB/s eta 0:00:02
#    ------------------------- -------------- 6.0/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.4 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 3.9 MB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, typing_extensions, pysocks, outcome, trio, trio-websocket, selenium
#
#    ---------------------------------------- 0/8 [sortedcontainers]
#    ----- ---------------------------------- 1/8 [wsproto]
#   Attempting uninstall: typing_extensions
#    ----- ---------------------------------- 1/8 [wsproto]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#     Found existing installation: typing_extensions 4.13.2
#    ---------- ----------------------------- 2/8 [typing_extensions]
#     Uninstalling typing_extensions-4.13.2:
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.13.2
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    -------------------- ------------------- 4/8 [outcome]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------------ --------- 6/8 [trio-websocket]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ---------------------------------------- 8/8 [selenium]
#
# Successfully installed outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.34.0 sortedcontainers-2.4.0 trio-0.30.0 trio-websocket-0.12.2 typing_extensions-4.14.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\nidak\appdata\local\programs\python\python313\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.19.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
📊 Customer Sentiment Analysis - iPhone 15 128GB
###Objective: Analyze customer sentiment using reviews from Flipkart for the iPhone 15 128GB model 
using scraping, preprocessing, sentiment classification, and visualization.###

# %%
#DATA COLLECTION (WEB SCRAPING)
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import nltk
from textblob import TextBlob
import requests
import re


#START CHROME WEBDRIVER
driver = webdriver.Chrome()

# %%
📥 Data Loading

# %%
# INITIALIZE LISTS TO STORE DATA
name=[]
rating=[]
review=[]
City = []
#FLIPKART PRODUCT REVIEWS URL
url = """https://www.flipkart.com/apple-iphone-15-blue-128-gb/product-reviews/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZY7RHDU7&marketplace=FLIPKART"""
#SCRAPE MULTIPLE PAGES
for i in range(1,5):
    new_url = url + "&page=" +str(i)
    r = requests.get(new_url)
    soup = BeautifulSoup(r.text , "html.parser")
#EXTRACTING NAMES
    names = soup.find_all("p" , {"class" : "_2NsDsF AwS1CA"})
    for i in names:
        name.append(i.text)
    name
#EXTRACTING RATINGS
    ratings = soup.find_all("div" , {"class" : "XQDdHH Ga3i8K"})
    for i in ratings:
        rating.append(i.text)
    rating
#EXTRACTING REVIEWS
    reviews = soup.find_all("div" , {"class" : "ZmyHeo"})
    for i in reviews:
        review.append(i.text)
    review

            
print(len(name) , len(review) , len(rating))
# Out:
# 30 30 30

# %%
📊 Data Exploration

# %%
df = pd.DataFrame({"CUSTOMER NAME" : name , "RATING" : rating , "REVIEW" : review})
df
# Out:
#             CUSTOMER NAME RATING  \
# 0         Neeraj  Chouhan      5
# 1          bijaya mohanty      5
# 2                  Ajin V      5
# 3        Mousam  Guha Roy      4
# 4       Flipkart Customer      5
# 5            Rishabh  Jha      5
# 6         Prithivi Boruah      5
# 7            Nikhil Kumar      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10        Saurabh Gothwad      5
# 11  Sheetla Prasad Maurya      4
# 12           Rahul Shedge      5
# 13         Kriti Customer      5
# 14             Talim (sk)      5
# 15          mohit  yadav       5
# 16         Afzol  Hussain      5
# 17              Raj Singh      5
# 18          Sandip Mandal      5
# 19            AYUSH singh      5
# 20      CHETAN  TILWALIA       5
# 21  VinodKUMAR VinodKUMAR      4
# 22  Varsha Sadanand Salve      5
# 23          Ankit  Verma       4
# 24      Flipkart Customer      5
# 25             Suman Jain      5
# 26      Flipkart Customer      4
# 27        Anubhav Chauhan      5
# 28          Praveen Kumar      5
# 29           Zeeshan Khan      5
#
#                                                REVIEW
# 0   Amezing  camera and all over best phone👌READ MORE
# 1   Just go for it.Amazing one.Beautiful camera wi...
# 2                       High quality camera😍READ MORE
# 3                                  Very niceREAD MORE
# 4   Awesome photography experience. Battery backup...
# 5                               Awesome 🔥🔥☺️READ MORE
# 6       Camera Quality Is Improved Loving ItREAD MORE
# 7   Switch from OnePlus to iPhone I am stunned wit...
# 8   So beautiful, so elegant, just a vowww😍❤️READ ...
# 9   Awesome product very happy to hold this. Bette...
# 10                           Simply premium.READ MORE
# 11  Best mobile phoneCamera quality is very nice B...
# 12  Totally happy!Camera 5Battery 5 Display 5Desig...
# 13  Just loved the product , colour , design is wo...
# 14  I love this phone. The camera is amazing: its ...
# 15                                   Nice ❤️READ MORE
# 16  Thanks Flipkart I m glad such a beautiful iPho...
# 17                  for me its 10 out of 10✨READ MORE
# 18                                    Great!READ MORE
# 19  best camera and battery is also very good In l...
# 20                                    Nice 👌READ MORE
# 21                           Nice phone goodREAD MORE
# 22  The iPhone 15 exceeded my expectations in ever...
# 23      Awesome camra quality superb camra 😊READ MORE
# 24  Using this Iphone 15 from 1month and it has be...
# 25                          Simply Awesome 🤩READ MORE
# 26                              Nice productREAD MORE
# 27  I have recently switched from Android to ios, ...
# 28  This is my first iphone ever used loving it al...
# 29  Awesome quality I am very happy. Thank you Fli...

# %%
🧹 Data Cleaning

# %%
#DATA CLEANING
df["CUSTOMER NAME"] = df["CUSTOMER NAME"].str.title()
df["REVIEW"]= df["REVIEW"].str.replace("READ MORE" , "")
df
# Out:
#             CUSTOMER NAME RATING  \
# 0         Neeraj  Chouhan      5
# 1          Bijaya Mohanty      5
# 2                  Ajin V      5
# 3        Mousam  Guha Roy      4
# 4       Flipkart Customer      5
# 5            Rishabh  Jha      5
# 6         Prithivi Boruah      5
# 7            Nikhil Kumar      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10        Saurabh Gothwad      5
# 11  Sheetla Prasad Maurya      4
# 12           Rahul Shedge      5
# 13         Kriti Customer      5
# 14             Talim (Sk)      5
# 15          Mohit  Yadav       5
# 16         Afzol  Hussain      5
# 17              Raj Singh      5
# 18          Sandip Mandal      5
# 19            Ayush Singh      5
# 20      Chetan  Tilwalia       5
# 21  Vinodkumar Vinodkumar      4
# 22  Varsha Sadanand Salve      5
# 23          Ankit  Verma       4
# 24      Flipkart Customer      5
# 25             Suman Jain      5
# 26      Flipkart Customer      4
# 27        Anubhav Chauhan      5
# 28          Praveen Kumar      5
# 29           Zeeshan Khan      5
#
#                                                REVIEW
# 0            Amezing  camera and all over best phone👌
# 1   Just go for it.Amazing one.Beautiful camera wi...
# 2                                High quality camera😍
# 3                                           Very nice
# 4   Awesome photography experience. Battery backup...
# 5                                        Awesome 🔥🔥☺️
# 6                Camera Quality Is Improved Loving It
# 7   Switch from OnePlus to iPhone I am stunned wit...
# 8           So beautiful, so elegant, just a vowww😍❤️
# 9   Awesome product very happy to hold this. Bette...
# 10                                    Simply premium.
# 11  Best mobile phoneCamera quality is very nice B...
# 12  Totally happy!Camera 5Battery 5 Display 5Design 5
# 13  Just loved the product , colour , design is wo...
# 14  I love this phone. The camera is amazing: its ...
# 15                                            Nice ❤️
# 16  Thanks Flipkart I m glad such a beautiful iPho...
# 17                           for me its 10 out of 10✨
# 18                                             Great!
# 19  best camera and battery is also very good In l...
# 20                                             Nice 👌
# 21                                    Nice phone good
# 22  The iPhone 15 exceeded my expectations in ever...
# 23               Awesome camra quality superb camra 😊
# 24  Using this Iphone 15 from 1month and it has be...
# 25                                   Simply Awesome 🤩
# 26                                       Nice product
# 27  I have recently switched from Android to ios, ...
# 28  This is my first iphone ever used loving it al...
# 29  Awesome quality I am very happy. Thank you Fli...

# %%
📝 Text Preprocessing

# %%
def split_into_sentences(text):
    if not isinstance(text, str):
        return []
    return re.findall(r'[^.!?]+[.!?]', text)

# Apply the function
df["REVIEW1"] = df["REVIEW"].apply(split_into_sentences)
df
# Out:
#             CUSTOMER NAME RATING  \
# 0         Neeraj  Chouhan      5
# 1          Bijaya Mohanty      5
# 2                  Ajin V      5
# 3        Mousam  Guha Roy      4
# 4       Flipkart Customer      5
# 5            Rishabh  Jha      5
# 6         Prithivi Boruah      5
# 7            Nikhil Kumar      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10        Saurabh Gothwad      5
# 11  Sheetla Prasad Maurya      4
# 12           Rahul Shedge      5
# 13         Kriti Customer      5
# 14             Talim (Sk)      5
# 15          Mohit  Yadav       5
# 16         Afzol  Hussain      5
# 17              Raj Singh      5
# 18          Sandip Mandal      5
# 19            Ayush Singh      5
# 20      Chetan  Tilwalia       5
# 21  Vinodkumar Vinodkumar      4
# 22  Varsha Sadanand Salve      5
# 23          Ankit  Verma       4
# 24      Flipkart Customer      5
# 25             Suman Jain      5
# 26      Flipkart Customer      4
# 27        Anubhav Chauhan      5
# 28          Praveen Kumar      5
# 29           Zeeshan Khan      5
#
#                                                REVIEW  \
# 0            Amezing  camera and all over best phone👌
# 1   Just go for it.Amazing one.Beautiful camera wi...
# 2                                High quality camera😍
# 3                                           Very nice
# 4   Awesome photography experience. Battery backup...
# 5                                        Awesome 🔥🔥☺️
# 6                Camera Quality Is Improved Loving It
# 7   Switch from OnePlus to iPhone I am stunned wit...
# 8           So beautiful, so elegant, just a vowww😍❤️
# 9   Awesome product very happy to hold this. Bette...
# 10                                    Simply premium.
# 11  Best mobile phoneCamera quality is very nice B...
# 12  Totally happy!Camera 5Battery 5 Display 5Design 5
# 13  Just loved the product , colour , design is wo...
# 14  I love this phone. The camera is amazing: its ...
# 15                                            Nice ❤️
# 16  Thanks Flipkart I m glad such a beautiful iPho...
# 17                           for me its 10 out of 10✨
# 18                                             Great!
# 19  best camera and battery is also very good In l...
# 20                                             Nice 👌
# 21                                    Nice phone good
# 22  The iPhone 15 exceeded my expectations in ever...
# 23               Awesome camra quality superb camra 😊
# 24  Using this Iphone 15 from 1month and it has be...
# 25                                   Simply Awesome 🤩
# 26                                       Nice product
# 27  I have recently switched from Android to ios, ...
# 28  This is my first iphone ever used loving it al...
# 29  Awesome quality I am very happy. Thank you Fli...
#
#                                               REVIEW1
# 0                                                  []
# 1                     [Just go for it., Amazing one.]
# 2                                                  []
# 3                                                  []
# 4   [Awesome photography experience.,  Battery bac...
# 5                                                  []
# 6                                                  []
# 7   [Switch from OnePlus to iPhone I am stunned wi...
# 8                                                  []
# 9   [Awesome product very happy to hold this.,  Be...
# 10                                  [Simply premium.]
# 11  [Best mobile phoneCamera quality is very nice ...
# 12                                   [Totally happy!]
# 13                                                 []
# 14                               [I love this phone.]
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                           [Great!]
# 19  [best camera and battery is also very good In ...
# 20                                                 []
# 21                                                 []
# 22  [The iPhone 15 exceeded my expectations in eve...
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27  [I have recently switched from Android to ios,...
# 28                                                 []
# 29  [Awesome quality I am very happy.,  Thank you ...

# %%
🧠 Sentiment Analysis

# %%
import pandas as pd
from textblob import blob
def get_polarity(sentences):
    return [TextBlob(sentence).sentiment.polarity for sentence in sentences]
df["Polarity"] = df["REVIEW1"].apply(get_polarity)
df
df["Subjectivity"] = df["REVIEW"].apply(lambda x : TextBlob(x).sentiment.subjectivity)
df
# Out:
#             CUSTOMER NAME RATING  \
# 0         Neeraj  Chouhan      5
# 1          Bijaya Mohanty      5
# 2                  Ajin V      5
# 3        Mousam  Guha Roy      4
# 4       Flipkart Customer      5
# 5            Rishabh  Jha      5
# 6         Prithivi Boruah      5
# 7            Nikhil Kumar      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10        Saurabh Gothwad      5
# 11  Sheetla Prasad Maurya      4
# 12           Rahul Shedge      5
# 13         Kriti Customer      5
# 14             Talim (Sk)      5
# 15          Mohit  Yadav       5
# 16         Afzol  Hussain      5
# 17              Raj Singh      5
# 18          Sandip Mandal      5
# 19            Ayush Singh      5
# 20      Chetan  Tilwalia       5
# 21  Vinodkumar Vinodkumar      4
# 22  Varsha Sadanand Salve      5
# 23          Ankit  Verma       4
# 24      Flipkart Customer      5
# 25             Suman Jain      5
# 26      Flipkart Customer      4
# 27        Anubhav Chauhan      5
# 28          Praveen Kumar      5
# 29           Zeeshan Khan      5
#
#                                                REVIEW  \
# 0            Amezing  camera and all over best phone👌
# 1   Just go for it.Amazing one.Beautiful camera wi...
# 2                                High quality camera😍
# 3                                           Very nice
# 4   Awesome photography experience. Battery backup...
# 5                                        Awesome 🔥🔥☺️
# 6                Camera Quality Is Improved Loving It
# 7   Switch from OnePlus to iPhone I am stunned wit...
# 8           So beautiful, so elegant, just a vowww😍❤️
# 9   Awesome product very happy to hold this. Bette...
# 10                                    Simply premium.
# 11  Best mobile phoneCamera quality is very nice B...
# 12  Totally happy!Camera 5Battery 5 Display 5Design 5
# 13  Just loved the product , colour , design is wo...
# 14  I love this phone. The camera is amazing: its ...
# 15                                            Nice ❤️
# 16  Thanks Flipkart I m glad such a beautiful iPho...
# 17                           for me its 10 out of 10✨
# 18                                             Great!
# 19  best camera and battery is also very good In l...
# 20                                             Nice 👌
# 21                                    Nice phone good
# 22  The iPhone 15 exceeded my expectations in ever...
# 23               Awesome camra quality superb camra 😊
# 24  Using this Iphone 15 from 1month and it has be...
# 25                                   Simply Awesome 🤩
# 26                                       Nice product
# 27  I have recently switched from Android to ios, ...
# 28  This is my first iphone ever used loving it al...
# 29  Awesome quality I am very happy. Thank you Fli...
#
#                                               REVIEW1  \
# 0                                                  []
# 1                     [Just go for it., Amazing one.]
# 2                                                  []
# 3                                                  []
# 4   [Awesome photography experience.,  Battery bac...
# 5                                                  []
# 6                                                  []
# 7   [Switch from OnePlus to iPhone I am stunned wi...
# 8                                                  []
# 9   [Awesome product very happy to hold this.,  Be...
# 10                                  [Simply premium.]
# 11  [Best mobile phoneCamera quality is very nice ...
# 12                                   [Totally happy!]
# 13                                                 []
# 14                               [I love this phone.]
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                           [Great!]
# 19  [best camera and battery is also very good In ...
# 20                                                 []
# 21                                                 []
# 22  [The iPhone 15 exceeded my expectations in eve...
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27  [I have recently switched from Android to ios,...
# 28                                                 []
# 29  [Awesome quality I am very happy.,  Thank you ...
#
#                                           Polarity  Subjectivity
# 0                                               []      0.300000
# 1                        [0.0, 0.6000000000000001]      0.633333
# 2                                               []      0.540000
# 3                                               []      1.000000
# 4                                  [1.0, 0.7, 0.5]      0.700000
# 5                                               []      1.000000
# 6                                               []      0.950000
# 7                                       [0.0, 1.0]      1.000000
# 8                                               []      1.000000
# 9   [1.0, 0.5, 0.5, 0.0, -0.1, 0.6666666666666666]      0.557407
# 10                                           [0.0]      0.357143
# 11                                         [0.738]      0.676000
# 12                                           [1.0]      0.750000
# 13                                              []      0.758333
# 14                                           [0.5]      0.833333
# 15                                              []      1.000000
# 16                                              []      0.675000
# 17                                              []      0.000000
# 18                                           [1.0]      0.750000
# 19                                         [0.534]      0.418095
# 20                                              []      1.000000
# 21                                              []      0.800000
# 22                       [0.0, 0.5, 0.9, 0.5, 0.5]      0.792857
# 23                                              []      1.000000
# 24                                              []      0.300000
# 25                                              []      1.000000
# 26                                              []      1.000000
# 27                [0.23833333333333337, 0.78, 0.5]      0.689000
# 28                                              []      0.461111
# 29                                      [1.0, 0.0]      1.000000

# %%
from statistics import mean
def calculate_average_polarity(polarities):
    return mean(polarities) if polarities else 0
df["Average_Polarity"] = df["Polarity"].apply(calculate_average_polarity)
df.head(10)
# Out:
#         CUSTOMER NAME RATING  \
# 0     Neeraj  Chouhan      5
# 1      Bijaya Mohanty      5
# 2              Ajin V      5
# 3    Mousam  Guha Roy      4
# 4   Flipkart Customer      5
# 5        Rishabh  Jha      5
# 6     Prithivi Boruah      5
# 7        Nikhil Kumar      5
# 8        Akshay Meena      5
# 9  Arunji Govindaraju      5
#
#                                               REVIEW  \
# 0           Amezing  camera and all over best phone👌
# 1  Just go for it.Amazing one.Beautiful camera wi...
# 2                               High quality camera😍
# 3                                          Very nice
# 4  Awesome photography experience. Battery backup...
# 5                                       Awesome 🔥🔥☺️
# 6               Camera Quality Is Improved Loving It
# 7  Switch from OnePlus to iPhone I am stunned wit...
# 8          So beautiful, so elegant, just a vowww😍❤️
# 9  Awesome product very happy to hold this. Bette...
#
#                                              REVIEW1  \
# 0                                                 []
# 1                    [Just go for it., Amazing one.]
# 2                                                 []
# 3                                                 []
# 4  [Awesome photography experience.,  Battery bac...
# 5                                                 []
# 6                                                 []
# 7  [Switch from OnePlus to iPhone I am stunned wi...
# 8                                                 []
# 9  [Awesome product very happy to hold this.,  Be...
#
#                                          Polarity  Subjectivity  \
# 0                                              []      0.300000
# 1                       [0.0, 0.6000000000000001]      0.633333
# 2                                              []      0.540000
# 3                                              []      1.000000
# 4                                 [1.0, 0.7, 0.5]      0.700000
# 5                                              []      1.000000
# 6                                              []      0.950000
# 7                                      [0.0, 1.0]      1.000000
# 8                                              []      1.000000
# 9  [1.0, 0.5, 0.5, 0.0, -0.1, 0.6666666666666666]      0.557407
#
#    Average_Polarity
# 0          0.000000
# 1          0.300000
# 2          0.000000
# 3          0.000000
# 4          0.733333
# 5          0.000000
# 6          0.000000
# 7          0.500000
# 8          0.000000
# 9          0.427778

# %%
def sentiment(pol):
    if pol >= 0.75:
        return "Extremely Positive"
    elif pol > 0:
        return "Positive"
    elif pol == 0:
        return "Neutral"
    elif pol <= -0.75:
        return "Negative"
    else :
        return "Extremely Negative"
df["Sentiment"]=df["Average_Polarity"].apply(sentiment)
df
# Out:
#             CUSTOMER NAME RATING  \
# 0         Neeraj  Chouhan      5
# 1          Bijaya Mohanty      5
# 2                  Ajin V      5
# 3        Mousam  Guha Roy      4
# 4       Flipkart Customer      5
# 5            Rishabh  Jha      5
# 6         Prithivi Boruah      5
# 7            Nikhil Kumar      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10        Saurabh Gothwad      5
# 11  Sheetla Prasad Maurya      4
# 12           Rahul Shedge      5
# 13         Kriti Customer      5
# 14             Talim (Sk)      5
# 15          Mohit  Yadav       5
# 16         Afzol  Hussain      5
# 17              Raj Singh      5
# 18          Sandip Mandal      5
# 19            Ayush Singh      5
# 20      Chetan  Tilwalia       5
# 21  Vinodkumar Vinodkumar      4
# 22  Varsha Sadanand Salve      5
# 23          Ankit  Verma       4
# 24      Flipkart Customer      5
# 25             Suman Jain      5
# 26      Flipkart Customer      4
# 27        Anubhav Chauhan      5
# 28          Praveen Kumar      5
# 29           Zeeshan Khan      5
#
#                                                REVIEW  \
# 0            Amezing  camera and all over best phone👌
# 1   Just go for it.Amazing one.Beautiful camera wi...
# 2                                High quality camera😍
# 3                                           Very nice
# 4   Awesome photography experience. Battery backup...
# 5                                        Awesome 🔥🔥☺️
# 6                Camera Quality Is Improved Loving It
# 7   Switch from OnePlus to iPhone I am stunned wit...
# 8           So beautiful, so elegant, just a vowww😍❤️
# 9   Awesome product very happy to hold this. Bette...
# 10                                    Simply premium.
# 11  Best mobile phoneCamera quality is very nice B...
# 12  Totally happy!Camera 5Battery 5 Display 5Design 5
# 13  Just loved the product , colour , design is wo...
# 14  I love this phone. The camera is amazing: its ...
# 15                                            Nice ❤️
# 16  Thanks Flipkart I m glad such a beautiful iPho...
# 17                           for me its 10 out of 10✨
# 18                                             Great!
# 19  best camera and battery is also very good In l...
# 20                                             Nice 👌
# 21                                    Nice phone good
# 22  The iPhone 15 exceeded my expectations in ever...
# 23               Awesome camra quality superb camra 😊
# 24  Using this Iphone 15 from 1month and it has be...
# 25                                   Simply Awesome 🤩
# 26                                       Nice product
# 27  I have recently switched from Android to ios, ...
# 28  This is my first iphone ever used loving it al...
# 29  Awesome quality I am very happy. Thank you Fli...
#
#                                               REVIEW1  \
# 0                                                  []
# 1                     [Just go for it., Amazing one.]
# 2                                                  []
# 3                                                  []
# 4   [Awesome photography experience.,  Battery bac...
# 5                                                  []
# 6                                                  []
# 7   [Switch from OnePlus to iPhone I am stunned wi...
# 8                                                  []
# 9   [Awesome product very happy to hold this.,  Be...
# 10                                  [Simply premium.]
# 11  [Best mobile phoneCamera quality is very nice ...
# 12                                   [Totally happy!]
# 13                                                 []
# 14                               [I love this phone.]
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                           [Great!]
# 19  [best camera and battery is also very good In ...
# 20                                                 []
# 21                                                 []
# 22  [The iPhone 15 exceeded my expectations in eve...
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27  [I have recently switched from Android to ios,...
# 28                                                 []
# 29  [Awesome quality I am very happy.,  Thank you ...
#
#                                           Polarity  Subjectivity  \
# 0                                               []      0.300000
# 1                        [0.0, 0.6000000000000001]      0.633333
# 2                                               []      0.540000
# 3                                               []      1.000000
# 4                                  [1.0, 0.7, 0.5]      0.700000
# 5                                               []      1.000000
# 6                                               []      0.950000
# 7                                       [0.0, 1.0]      1.000000
# 8                                               []      1.000000
# 9   [1.0, 0.5, 0.5, 0.0, -0.1, 0.6666666666666666]      0.557407
# 10                                           [0.0]      0.357143
# 11                                         [0.738]      0.676000
# 12                                           [1.0]      0.750000
# 13                                              []      0.758333
# 14                                           [0.5]      0.833333
# 15                                              []      1.000000
# 16                                              []      0.675000
# 17                                              []      0.000000
# 18                                           [1.0]      0.750000
# 19                                         [0.534]      0.418095
# 20                                              []      1.000000
# 21                                              []      0.800000
# 22                       [0.0, 0.5, 0.9, 0.5, 0.5]      0.792857
# 23                                              []      1.000000
# 24                                              []      0.300000
# 25                                              []      1.000000
# 26                                              []      1.000000
# 27                [0.23833333333333337, 0.78, 0.5]      0.689000
# 28                                              []      0.461111
# 29                                      [1.0, 0.0]      1.000000
#
#     Average_Polarity           Sentiment
# 0           0.000000             Neutral
# 1           0.300000            Positive
# 2           0.000000             Neutral
# 3           0.000000             Neutral
# 4           0.733333            Positive
# 5           0.000000             Neutral
# 6           0.000000             Neutral
# 7           0.500000            Positive
# 8           0.000000             Neutral
# 9           0.427778            Positive
# 10          0.000000             Neutral
# 11          0.738000            Positive
# 12          1.000000  Extremely Positive
# 13          0.000000             Neutral
# 14          0.500000            Positive
# 15          0.000000             Neutral
# 16          0.000000             Neutral
# 17          0.000000             Neutral
# 18          1.000000  Extremely Positive
# 19          0.534000            Positive
# 20          0.000000             Neutral
# 21          0.000000             Neutral
# 22          0.480000            Positive
# 23          0.000000             Neutral
# 24          0.000000             Neutral
# 25          0.000000             Neutral
# 26          0.000000             Neutral
# 27          0.506111            Positive
# 28          0.000000             Neutral
# 29          0.500000            Positive

# %%
pol = df["Average_Polarity"].mean()

# %%
if pol <= -0.6:
    print("Extremely Negative")
elif pol <= -0.2:
    print("Negative")
elif pol <0.2:
    print("Neutral")
elif pol <= 0.6:
    print("Positive")
else:
    print("Extremely Positive")
# Out:
# Positive
